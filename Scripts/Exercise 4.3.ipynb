# %%
#Import Libraries
import pandas as pd 
import numpy as np 
import os

# %%
# importing data

# %%
#First line of code importing Orders CSV file

# %%
df = pd.read_csv(r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Original Data /orders.csv', index_col = False)

# %%
path= r'/Users/mattrauth/Desktop/Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/mattrauth/Desktop/Instacart Basket Analysis'

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df.tail()
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 1048570   1805240    63100    prior             1          0
# 1048571   2719402    63100    prior             2          0
# 1048572   2855250    63100    prior             3          2
# 1048573   2355832    63100    prior             4          5
# 1048574   2362552    63100    train             5          1
#
#          order_hour_of_day  days_since_prior_order
# 1048570                 11                     NaN
# 1048571                  8                    14.0
# 1048572                 13                    16.0
# 1048573                 16                    30.0
# 1048574                 13                    30.0

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (1048575, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 7 columns):
# order_id                  1048575 non-null int64
# user_id                   1048575 non-null int64
# eval_set                  1048575 non-null object
# order_number              1048575 non-null int64
# order_dow                 1048575 non-null int64
# order_hour_of_day         1048575 non-null int64
# days_since_prior_order    985475 non-null float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 56.0+ MB

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
