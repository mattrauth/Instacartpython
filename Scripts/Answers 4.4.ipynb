# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
df_ords= pd.read_csv(r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Original Data /orders.csv', index_col = False)

# %%
# 2. Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# 5         3367565        1             6          2                  7
# 6          550135        1             7          1                  9
# 7         3108588        1             8          1                 14
# 8         2295261        1             9          1                 16
# 9         2550362        1            10          4                  8
# 10        1187899        1            11          4                  8
# 11        2168274        2             1          2                 11
# 12        1501582        2             2          5                 10
# 13        1901567        2             3          1                 10
# 14         738281        2             4          2                 10
# 15        1673511        2             5          3                 11
# 16        1199898        2             6          2                  9
# 17        3194192        2             7          2                 12
# 18         788338        2             8          1                 15
# 19        1718559        2             9          2                  9
# 20        1447487        2            10          1                 11
# 21        1402090        2            11          1                 10
# 22        3186735        2            12          1                  9
# 23        3268552        2            13          4                 11
# 24         839880        2            14          3                 10
# 25        1492625        2            15          1                 11
# 26        1374495        3             1          1                 14
# 27         444309        3             2          3                 19
# 28        3002854        3             3          3                 16
# 29        2037211        3             4          2                 18
# ...           ...      ...           ...        ...                ...
# 1048545   1805250    63098             5          0                 13
# 1048546   1402287    63098             6          1                 12
# 1048547   2672959    63098             7          4                 10
# 1048548   3027299    63098             8          5                 11
# 1048549   3287901    63098             9          0                 12
# 1048550   2093178    63098            10          4                 10
# 1048551   1697311    63098            11          0                  8
# 1048552   2030718    63098            12          5                  9
# 1048553   2563452    63098            13          0                  9
# 1048554     96551    63098            14          0                  8
# 1048555   1096298    63098            15          5                 15
# 1048556   1877750    63099             1          0                 10
# 1048557   1394165    63099             2          2                 19
# 1048558   2817440    63099             3          3                 10
# 1048559   2100528    63099             4          3                  9
# 1048560   3055159    63099             5          1                 15
# 1048561   2391525    63099             6          4                 10
# 1048562   2537757    63099             7          2                 11
# 1048563   3046709    63099             8          5                 22
# 1048564   3351770    63099             9          3                 11
# 1048565    886164    63099            10          0                 12
# 1048566    642909    63099            11          4                 11
# 1048567   2154500    63099            12          4                 16
# 1048568   1304124    63099            13          6                  9
# 1048569   2625264    63099            14          0                 13
# 1048570   1805240    63100             1          0                 11
# 1048571   2719402    63100             2          0                  8
# 1048572   2855250    63100             3          2                 13
# 1048573   2355832    63100             4          5                 16
# 1048574   2362552    63100             5          1                 13
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# 2                          21.0
# 3                          29.0
# 4                          28.0
# 5                          19.0
# 6                          20.0
# 7                          14.0
# 8                           0.0
# 9                          30.0
# 10                         14.0
# 11                          NaN
# 12                         10.0
# 13                          3.0
# 14                          8.0
# 15                          8.0
# 16                         13.0
# 17                         14.0
# 18                         27.0
# 19                          8.0
# 20                          6.0
# 21                         30.0
# 22                         28.0
# 23                         30.0
# 24                         13.0
# 25                         30.0
# 26                          NaN
# 27                          9.0
# 28                         21.0
# 29                         20.0
# ...                         ...
# 1048545                     8.0
# 1048546                    15.0
# 1048547                    10.0
# 1048548                    30.0
# 1048549                    16.0
# 1048550                    25.0
# 1048551                    10.0
# 1048552                    12.0
# 1048553                    16.0
# 1048554                    30.0
# 1048555                    30.0
# 1048556                     NaN
# 1048557                    30.0
# 1048558                    15.0
# 1048559                    30.0
# 1048560                    12.0
# 1048561                    10.0
# 1048562                    26.0
# 1048563                    30.0
# 1048564                    19.0
# 1048565                     4.0
# 1048566                    11.0
# 1048567                     7.0
# 1048568                    30.0
# 1048569                    30.0
# 1048570                     NaN
# 1048571                    14.0
# 1048572                    16.0
# 1048573                    30.0
# 1048574                    30.0
#
# [1048575 rows x 6 columns]

# %%
# 3. Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.
df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
# 4. Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.
df_ords_2['order_hour_of_day'].value_counts()
# Out:
# 10    88228
# 11    87087
# 14    86905
# 15    86888
# 13    85652
# 12    84204
# 16    83421
# 9     78737
# 17    69960
# 18    56284
# 8     54868
# 19    43076
# 20    31735
# 7     28199
# 21    23972
# 22    18824
# 23    12112
# 6      9253
# 0      6881
# 1      3698
# 5      2882
# 2      2312
# 4      1748
# 3      1649
# Name: order_hour_of_day, dtype: int64

# %%
# 5. Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.
df_prods = pd.read_csv(r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Original Data /Products.csv', index_col = False)

# %%
df_dep = pd.read_csv(r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Original Data /products.csv', index_col = False)

# %%
df_dep.T
# A. 4 = produce
# Out:
#                                     0                 1      \
# product_id                              1                 2
# product_name   Chocolate Sandwich Cookies  All-Seasons Salt
# aisle_id                               61               104
# department_id                          19                13
# prices                                5.8               9.3
#
#                                               2      \
# product_id                                        3
# product_name   Robust Golden Unsweetened Oolong Tea
# aisle_id                                         94
# department_id                                     7
# prices                                          4.5
#
#                                                            3      \
# product_id                                                     4
# product_name   Smart Ones Classic Favorites Mini Rigatoni Wit...
# aisle_id                                                      38
# department_id                                                  1
# prices                                                      10.5
#
#                                    4             5      \
# product_id                             5             6
# product_name   Green Chile Anytime Sauce  Dry Nose Oil
# aisle_id                               5            11
# department_id                         13            11
# prices                               4.3           2.6
#
#                                         6      \
# product_id                                  7
# product_name   Pure Coconut Water With Orange
# aisle_id                                   98
# department_id                               7
# prices                                    4.4
#
#                                            7      \
# product_id                                     8
# product_name   Cut Russet Potatoes Steam N' Mash
# aisle_id                                     116
# department_id                                  1
# prices                                       1.1
#
#                                            8      \
# product_id                                     9
# product_name   Light Strawberry Blueberry Yogurt
# aisle_id                                     120
# department_id                                 16
# prices                                         7
#
#                                                         9      \
# product_id                                                 10
# product_name   Sparkling Orange Juice & Prickly Pear Beverage
# aisle_id                                                  115
# department_id                                               7
# prices                                                    8.4
#
#                         ...                              49683  \
# product_id              ...                              49679
# product_name            ...            Famous Chocolate Wafers
# aisle_id                ...                                 61
# department_id           ...                                 19
# prices                  ...                                  6
#
#                                             49684  \
# product_id                                  49680
# product_name   All Natural Creamy Caesar Dressing
# aisle_id                                       89
# department_id                                  13
# prices                                        4.9
#
#                                                  49685               49686  \
# product_id                                       49681               49682
# product_name   Spaghetti with Meatballs and Sauce Meal  California Limeade
# aisle_id                                            38                  98
# department_id                                        1                   7
# prices                                             6.9                 4.3
#
#                         49687                                      49688  \
# product_id              49683                                      49684
# product_name   Cucumber Kirby  Vodka, Triple Distilled, Twist of Vanilla
# aisle_id                   83                                        124
# department_id               4                                          5
# prices                   13.2                                        5.3
#
#                                             49689             49690  \
# product_id                                  49685             49686
# product_name   En Croute Roast Hazelnut Cranberry  Artisan Baguette
# aisle_id                                       42               112
# department_id                                   1                 3
# prices                                        3.1               7.8
#
#                                                     49691  \
# product_id                                          49687
# product_name   Smartblend Healthy Metabolism Dry Cat Food
# aisle_id                                               41
# department_id                                           8
# prices                                                4.7
#
#                                 49692
# product_id                      49688
# product_name   Fresh Foaming Cleanser
# aisle_id                           73
# department_id                      11
# prices                           13.5
#
# [5 rows x 49693 columns]

# %%
# 6. The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.
df_prods['department_id']==14
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 49663    False
# 49664    False
# 49665    False
# 49666    False
# 49667     True
# 49668    False
# 49669    False
# 49670    False
# 49671    False
# 49672    False
# 49673    False
# 49674    False
# 49675    False
# 49676    False
# 49677    False
# 49678    False
# 49679    False
# 49680    False
# 49681    False
# 49682    False
# 49683    False
# 49684    False
# 49685    False
# 49686    False
# 49687    False
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==14]
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# 215           216                  Gluten Free Oatmeal, Variety Pack
# 221           222                          Honey Nut Oatmeal Squares
# 237           238                       Alpha-Bits Multigrain Cereal
# 251           252                                 Waffles, Red Berry
# 287           288  Original Sprouted Grains Protein & Fiber Hot O...
# 339           340                         Eco-Pac Kamut Puffs Cereal
# 364           365                                    Cheerios Cereal
# 437           438  Special K Vanilla Cappuccino Protein Breakfast...
# 456           457                                Whole Wheat Fig Bar
# 510           510            Protein Blend Honey Oats & Seeds Cereal
# 550           550                          Granola, Veritas, Organic
# 565           565            Light and Fluffy  Blueberry Pancake Mix
# 588           588                          Special K Original Cereal
# 637           637                    Multigrain Peanut Butter Cereal
# 661           661                         Sweet Lemon Rain Dance Bar
# 691           691           Organic Promise Strawberry Fields Cereal
# 697           697                       Quick Cooking Steel Cut Oats
# 745           745  Complete Funfetti Buttermilk Pancake & Waffle Mix
# 812           812  Healthy Grains Oats & Honey Clusters with Toas...
# 853           853                  Crunchy Granola Bars Variety Pack
# 910           910  Nutri-Grain Harvest Hearty Breakfast Bars Coun...
# 978           978                                Mallow Oats Cereals
# 994           994                Shake n Pour Buttermilk Pancake Mix
# 1049         1049  Special K Protein Chewy Granola Bars Almond Ho...
# 1087         1087                    Sunrise Crunchy Cinnamon Cereal
# ...           ...                                                ...
# 47999       47995  Weight Control Maple & Brown Sugar Instant Oat...
# 48011       48007                       Flax Plus Raisin Bran Cereal
# 48044       48040                              Kix Crispy Corn Puffs
# 48062       48058     Organic Honey'd Corn Flakes Cereal Gluten Free
# 48110       48106              Traditional Ancient Grains Hot Cereal
# 48162       48158           Blackberry Graham Soft-Baked Cereal Bars
# 48214       48210                     Whole Wheat Blueberry Fig Bars
# 48385       48381                    Blueberry Chia Buckwheat Muesli
# 48543       48539     Instant Gluten-Free Brown Sugar & Flax Oatmeal
# 48588       48584                            Cocoa Dyno-Bites Cereal
# 48677       48673  Raw Pure & Simple Organic Bare with Flax Insta...
# 48721       48717                  Real Medleys Apple Walnut Oatmeal
# 48743       48739                   Limited Edition Mini Trix Cereal
# 48746       48742                    Quick 1 Minute Whole Grain Oats
# 48798       48794                        Froot Loops Bloopers Cereal
# 48948       48944        Variety Pack of Gluten Free Instant Oatmeal
# 48959       48955                           Chocolate Chip Crisp Bar
# 49004       49000                              Blueberry Bliss Snack
# 49044       49040                            Blueberry Minute Muffin
# 49083       49079                    Special K Vanilla Almond Cereal
# 49111       49107                  Nutri-Grain Raspberry Cereal Bars
# 49115       49111                           Original Instant Oatmeal
# 49139       49135                  Cereal, Superfood, Acai Blueberry
# 49145       49141                              Gluten Free Rice Chex
# 49245       49241                       Organic Original Hot Oatmeal
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# 67          130             14    13.7
# 89          121             14     3.9
# 210         130             14     3.6
# 215         130             14     4.5
# 221         121             14     1.1
# 237         121             14    11.9
# 251         121             14     4.9
# 287         130             14     4.5
# 339         121             14     7.8
# 364         121             14    10.5
# 437          48             14     9.5
# 456          48             14     5.3
# 510         121             14     8.3
# 550          57             14     1.7
# 565         130             14     5.8
# 588         121             14    12.2
# 637         121             14     7.6
# 661          48             14     1.8
# 691         121             14     2.7
# 697         130             14    11.7
# 745         130             14     7.5
# 812          57             14    14.4
# 853          48             14     8.7
# 910          48             14     5.8
# 978         121             14     4.4
# 994         130             14    13.4
# 1049         48             14     2.9
# 1087        121             14    11.6
# ...         ...            ...     ...
# 47999       130             14    10.3
# 48011       121             14     5.6
# 48044       121             14     9.9
# 48062       121             14    10.9
# 48110       130             14    11.2
# 48162        48             14     4.6
# 48214        48             14     6.2
# 48385        57             14     4.1
# 48543       130             14     5.2
# 48588       121             14     3.3
# 48677       130             14    13.0
# 48721       130             14     1.1
# 48743       121             14    12.6
# 48746       130             14     5.9
# 48798       121             14     1.2
# 48948       121             14     2.9
# 48959        48             14     2.8
# 49004        48             14     7.3
# 49044       130             14     9.4
# 49083       121             14     2.2
# 49111        48             14     1.3
# 49115       130             14     2.9
# 49139       121             14     6.6
# 49145       121             14    12.3
# 49245       130             14    13.7
# 49330       121             14     9.1
# 49395       130             14     2.0
# 49547       121             14    10.8
# 49637       130             14    14.2
# 49667        57             14    10.2
#
# [1116 rows x 5 columns]

# %%
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
# 7. They’d also like to see details about customers who might be throwing dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.
df_prods.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 11          12                         Chocolate Fudge Layer Cake       119
# 12          13                                  Saline Nasal Mist        11
# 13          14                     Fresh Scent Dishwasher Cleaner        74
# 14          15                           Overnight Diapers Size 6        56
# 15          16                      Mint Chocolate Flavored Syrup       103
# 16          17                                  Rendered Duck Fat        35
# 17          18                Pizza for One Suprema  Frozen Pizza        79
# 18          19   Gluten Free Quinoa Three Cheese & Mushroom Blend        63
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
#
#     department_id  prices
# 0              19     5.8
# 1              13     9.3
# 2               7     4.5
# 3               1    10.5
# 4              13     4.3
# 5              11     2.6
# 6               7     4.4
# 7               1     1.1
# 8              16     7.0
# 9               7     8.4
# 10              7     2.8
# 11              1     9.4
# 12             11     1.1
# 13             17     6.5
# 14             18    11.2
# 15             19     5.2
# 16             12    17.1
# 17              1    10.6
# 18              9    12.0
# 19              7     6.0

# %%
df_prods[df_prods['department_id'].isin(['5', '7', '12', '20'])]
# Out:
#        product_id                                       product_name  \
# 2               3               Robust Golden Unsweetened Oolong Tea
# 6               7                     Pure Coconut Water With Orange
# 9              10     Sparkling Orange Juice & Prickly Pear Beverage
# 10             11                                  Peach Mango Juice
# 16             17                                  Rendered Duck Fat
# 19             20     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 22             23                             Organic Turkey Burgers
# 34             35     Italian Herb Porcini Mushrooms Chicken Sausage
# 38             39           Daily Tangerine Citrus Flavored Beverage
# 39             40  Beef Hot Links Beef Smoked Sausage With Chile ...
# 43             44                        Sparkling Raspberry Seltzer
# 48             49      Vegetarian Grain Meat Sausages Italian - 4 CT
# 51             52                                Mirabelle Brut Rose
# 52             53              Whole Leaf Pure Aloe With Lemon Juice
# 61             62            Premium Deli Oven Roasted Turkey Breast
# 68             69                                                NaN
# 72             73                  Jasmine Tea Unfiltered Ginger Ale
# 73             74                    Artisan Chick'n & Apple Sausage
# 81             82                       All Natural 100% Apple Juice
# 83             84                                         Lamb Shank
# 84             85                               Soppressata Piccante
# 86             87                             Classics Earl Grey Tea
# 96             97                        Organic Chamomile Lemon Tea
# 108           109                             Grape Leaf Hummus Wrap
# 118           119                             Chardonnay Paso Robles
# 137           138                                 Olli Napoli Salami
# 146           147                           Organic Ranch Veggie Dip
# 149           150                                          Brut Rosé
# 157           158  Smoked Ham & Oven Roasted Turkey Sub Sandwich Kit
# 166           167                        Sparkling Blush Grape Juice
# ...           ...                                                ...
# 49544       49540                            Pure Squeezed  Lemonade
# 49548       49544                            Cabernet Sauvignon Wine
# 49552       49548                    Cranberry Pomegranate Green Tea
# 49554       49550                          Tangerine Limeade Seltzer
# 49558       49554                              Roasted Garlic Hommus
# 49561       49557                     Loose Leaf Mild Yerba Mate Tea
# 49564       49560        Selects Natural Slow Roasted Chicken Breast
# 49566       49562                      Blanc De Noirs Sparkling Wine
# 49567       49563                          Jasmine Green Tea - 20 CT
# 49585       49581                       Pinto Bean and Cheese Pupusa
# 49588       49584    Herbal Supplement Milk Thistle Tea Bags - 24 CT
# 49602       49598          Hot Cocoa Mix With Marshmallows Envelopes
# 49607       49603             Peppermint Chocolate Caffeine Free Tea
# 49609       49605                         Classic Hummus Family Size
# 49610       49606                                Organic Natural Red
# 49613       49609           Very Berry Flavor Sparking Mineral Water
# 49616       49612                         White Grape Juice Cocktail
# 49619       49615                             Cran-Apple Juice Drink
# 49627       49623                  Freeze-Dried Powder Coconut Water
# 49641       49637  Passion Fruit Flavored Fruit Juice Cocktail Blend
# 49642       49638               Organic Superfirm Vacuum Packed Tofu
# 49655       49651                                       Beef Brisket
# 49659       49655                                        Apple Cider
# 49665       49661                                              Porto
# 49674       49670                                Beef Summer Sausage
# 49676       49672                             Cafe Mocha K-Cup Packs
# 49679       49675                Cinnamon Dolce Keurig Brewed K Cups
# 49680       49676                             Ultra Red Energy Drink
# 49686       49682                                 California Limeade
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
#
#        aisle_id  department_id  prices
# 2            94              7     4.5
# 6            98              7     4.4
# 9           115              7     8.4
# 10           31              7     2.8
# 16           35             12    17.1
# 19           98              7     6.0
# 22           49             12     8.2
# 34          106             12    15.1
# 38           64              7    12.5
# 39          106             12    22.5
# 43          115              7    12.2
# 48           14             20    10.1
# 51          134              5    14.4
# 52           98              7     4.7
# 61           96             20    14.6
# 68           26              7    11.8
# 72           77              7     8.3
# 73           14             20     3.0
# 81           98              7     6.4
# 83            7             12    24.3
# 84           96             20     8.9
# 86           94              7     9.1
# 96           94              7     8.4
# 108          13             20     7.1
# 118          62              5     5.5
# 137          96             20     5.1
# 146          67             20     3.4
# 149         134              5    12.9
# 157          96             20    14.0
# 166          77              7    13.8
# ...         ...            ...     ...
# 49544        31              7     9.1
# 49548        28              5     9.8
# 49552        94              7     8.5
# 49554       115              7    14.5
# 49558        67             20    14.8
# 49561        94              7    14.6
# 49564        96             20    14.5
# 49566       134              5     5.7
# 49567        94              7     6.4
# 49585        13             20    10.5
# 49588        94              7     7.0
# 49602        90              7     7.9
# 49607        94              7    11.7
# 49609        67             20     3.5
# 49610        28              5     6.8
# 49613       115              7    13.2
# 49616        77              7    14.3
# 49619        98              7    12.1
# 49627        90              7    12.0
# 49641        31              7    13.8
# 49642        14             20     9.0
# 49655       122             12    20.7
# 49659        98              7    10.7
# 49665       134              5     8.2
# 49674       106             12    19.2
# 49676        26              7     6.5
# 49679        26              7    14.0
# 49680        64              7    14.5
# 49686        98              7     4.3
# 49688       124              5     5.3
#
# [7650 rows x 5 columns]

# %%
df_dinner_parties = df_prods[df_prods['department_id'].isin(['5', '7', '12', '20'])]

# %%
df_dinner_parties.describe()
# Out:
#          product_id     aisle_id  department_id       prices
# count   7650.000000  7650.000000    7650.000000  7650.000000
# mean   24721.196601    66.286536       9.563268     9.012458
# std    14297.565684    36.844580       5.114123     4.997438
# min        3.000000     1.000000       5.000000     1.000000
# 25%    12402.500000    28.000000       7.000000     5.000000
# 50%    24803.000000    77.000000       7.000000     8.800000
# 75%    36977.250000    98.000000      12.000000    12.400000
# max    49684.000000   134.000000      20.000000    25.000000

# %%
# 8. It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?
# A 7650

# %%
# 9. Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.
df_ords['user_id']==1
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1048545    False
# 1048546    False
# 1048547    False
# 1048548    False
# 1048549    False
# 1048550    False
# 1048551    False
# 1048552    False
# 1048553    False
# 1048554    False
# 1048555    False
# 1048556    False
# 1048557    False
# 1048558    False
# 1048559    False
# 1048560    False
# 1048561    False
# 1048562    False
# 1048563    False
# 1048564    False
# 1048565    False
# 1048566    False
# 1048567    False
# 1048568    False
# 1048569    False
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Name: user_id, Length: 1048575, dtype: bool

# %%
df_ords[df_ords['user_id']==1]
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# 6                     20.0
# 7                     14.0
# 8                      0.0
# 9                     30.0
# 10                    14.0

# %%
df_user1 = df_ords[df_ords['user_id']==1]

# %%
# 10. You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?
df_user1.describe()
# Out:
#            order_id  user_id  order_number  order_dow  order_hour_of_day  \
# count  1.100000e+01     11.0     11.000000  11.000000          11.000000
# mean   1.923450e+06      1.0      6.000000   2.636364          10.090909
# std    1.071950e+06      0.0      3.316625   1.286291           3.477198
# min    4.315340e+05      1.0      1.000000   1.000000           7.000000
# 25%    8.690170e+05      1.0      3.500000   1.500000           7.500000
# 50%    2.295261e+06      1.0      6.000000   3.000000           8.000000
# 75%    2.544846e+06      1.0      8.500000   4.000000          13.000000
# max    3.367565e+06      1.0     11.000000   4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# 12. Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.
df_ords.to_csv (r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Prepared Data/ orders_wrangled.csv')

# %%
df_dep.T
# Out:
#                                     0                 1      \
# product_id                              1                 2
# product_name   Chocolate Sandwich Cookies  All-Seasons Salt
# aisle_id                               61               104
# department_id                          19                13
# prices                                5.8               9.3
#
#                                               2      \
# product_id                                        3
# product_name   Robust Golden Unsweetened Oolong Tea
# aisle_id                                         94
# department_id                                     7
# prices                                          4.5
#
#                                                            3      \
# product_id                                                     4
# product_name   Smart Ones Classic Favorites Mini Rigatoni Wit...
# aisle_id                                                      38
# department_id                                                  1
# prices                                                      10.5
#
#                                    4             5      \
# product_id                             5             6
# product_name   Green Chile Anytime Sauce  Dry Nose Oil
# aisle_id                               5            11
# department_id                         13            11
# prices                               4.3           2.6
#
#                                         6      \
# product_id                                  7
# product_name   Pure Coconut Water With Orange
# aisle_id                                   98
# department_id                               7
# prices                                    4.4
#
#                                            7      \
# product_id                                     8
# product_name   Cut Russet Potatoes Steam N' Mash
# aisle_id                                     116
# department_id                                  1
# prices                                       1.1
#
#                                            8      \
# product_id                                     9
# product_name   Light Strawberry Blueberry Yogurt
# aisle_id                                     120
# department_id                                 16
# prices                                         7
#
#                                                         9      \
# product_id                                                 10
# product_name   Sparkling Orange Juice & Prickly Pear Beverage
# aisle_id                                                  115
# department_id                                               7
# prices                                                    8.4
#
#                         ...                              49683  \
# product_id              ...                              49679
# product_name            ...            Famous Chocolate Wafers
# aisle_id                ...                                 61
# department_id           ...                                 19
# prices                  ...                                  6
#
#                                             49684  \
# product_id                                  49680
# product_name   All Natural Creamy Caesar Dressing
# aisle_id                                       89
# department_id                                  13
# prices                                        4.9
#
#                                                  49685               49686  \
# product_id                                       49681               49682
# product_name   Spaghetti with Meatballs and Sauce Meal  California Limeade
# aisle_id                                            38                  98
# department_id                                        1                   7
# prices                                             6.9                 4.3
#
#                         49687                                      49688  \
# product_id              49683                                      49684
# product_name   Cucumber Kirby  Vodka, Triple Distilled, Twist of Vanilla
# aisle_id                   83                                        124
# department_id               4                                          5
# prices                   13.2                                        5.3
#
#                                             49689             49690  \
# product_id                                  49685             49686
# product_name   En Croute Roast Hazelnut Cranberry  Artisan Baguette
# aisle_id                                       42               112
# department_id                                   1                 3
# prices                                        3.1               7.8
#
#                                                     49691  \
# product_id                                          49687
# product_name   Smartblend Healthy Metabolism Dry Cat Food
# aisle_id                                               41
# department_id                                           8
# prices                                                4.7
#
#                                 49692
# product_id                      49688
# product_name   Fresh Foaming Cleanser
# aisle_id                           73
# department_id                      11
# prices                           13.5
#
# [5 rows x 49693 columns]

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.reset_index()
# Out:
#            index                           0                 1  \
# 0     product_id                           1                 2
# 1   product_name  Chocolate Sandwich Cookies  All-Seasons Salt
# 2       aisle_id                          61               104
# 3  department_id                          19                13
# 4         prices                         5.8               9.3
#
#                                       2  \
# 0                                     3
# 1  Robust Golden Unsweetened Oolong Tea
# 2                                    94
# 3                                     7
# 4                                   4.5
#
#                                                    3  \
# 0                                                  4
# 1  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 2                                                 38
# 3                                                  1
# 4                                               10.5
#
#                            4             5                               6  \
# 0                          5             6                               7
# 1  Green Chile Anytime Sauce  Dry Nose Oil  Pure Coconut Water With Orange
# 2                          5            11                              98
# 3                         13            11                               7
# 4                        4.3           2.6                             4.4
#
#                                    7                                  8  \
# 0                                  8                                  9
# 1  Cut Russet Potatoes Steam N' Mash  Light Strawberry Blueberry Yogurt
# 2                                116                                120
# 3                                  1                                 16
# 4                                1.1                                  7
#
#             ...                              49683  \
# 0           ...                              49679
# 1           ...            Famous Chocolate Wafers
# 2           ...                                 61
# 3           ...                                 19
# 4           ...                                  6
#
#                                 49684  \
# 0                               49680
# 1  All Natural Creamy Caesar Dressing
# 2                                  89
# 3                                  13
# 4                                 4.9
#
#                                      49685               49686  \
# 0                                    49681               49682
# 1  Spaghetti with Meatballs and Sauce Meal  California Limeade
# 2                                       38                  98
# 3                                        1                   7
# 4                                      6.9                 4.3
#
#             49687                                      49688  \
# 0           49683                                      49684
# 1  Cucumber Kirby  Vodka, Triple Distilled, Twist of Vanilla
# 2              83                                        124
# 3               4                                          5
# 4            13.2                                        5.3
#
#                                 49689             49690  \
# 0                               49685             49686
# 1  En Croute Roast Hazelnut Cranberry  Artisan Baguette
# 2                                  42               112
# 3                                   1                 3
# 4                                 3.1               7.8
#
#                                         49691                   49692
# 0                                       49687                   49688
# 1  Smartblend Healthy Metabolism Dry Cat Food  Fresh Foaming Cleanser
# 2                                          41                      73
# 3                                           8                      11
# 4                                         4.7                    13.5
#
# [5 rows x 49694 columns]

# %%
new_header = df_dep_t.iloc[0]

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# product_id                          1                 2      \
# product_name   Chocolate Sandwich Cookies  All-Seasons Salt
# aisle_id                               61               104
# department_id                          19                13
# prices                                5.8               9.3
#
# product_id                                    3      \
# product_name   Robust Golden Unsweetened Oolong Tea
# aisle_id                                         94
# department_id                                     7
# prices                                          4.5
#
# product_id                                                 4      \
# product_name   Smart Ones Classic Favorites Mini Rigatoni Wit...
# aisle_id                                                      38
# department_id                                                  1
# prices                                                      10.5
#
# product_id                         5             6      \
# product_name   Green Chile Anytime Sauce  Dry Nose Oil
# aisle_id                               5            11
# department_id                         13            11
# prices                               4.3           2.6
#
# product_id                              7      \
# product_name   Pure Coconut Water With Orange
# aisle_id                                   98
# department_id                               7
# prices                                    4.4
#
# product_id                                 8      \
# product_name   Cut Russet Potatoes Steam N' Mash
# aisle_id                                     116
# department_id                                  1
# prices                                       1.1
#
# product_id                                 9      \
# product_name   Light Strawberry Blueberry Yogurt
# aisle_id                                     120
# department_id                                 16
# prices                                         7
#
# product_id                                              10     \
# product_name   Sparkling Orange Juice & Prickly Pear Beverage
# aisle_id                                                  115
# department_id                                               7
# prices                                                    8.4
#
# product_id              ...                              49679  \
# product_name            ...            Famous Chocolate Wafers
# aisle_id                ...                                 61
# department_id           ...                                 19
# prices                  ...                                  6
#
# product_id                                  49680  \
# product_name   All Natural Creamy Caesar Dressing
# aisle_id                                       89
# department_id                                  13
# prices                                        4.9
#
# product_id                                       49681               49682  \
# product_name   Spaghetti with Meatballs and Sauce Meal  California Limeade
# aisle_id                                            38                  98
# department_id                                        1                   7
# prices                                             6.9                 4.3
#
# product_id              49683                                      49684  \
# product_name   Cucumber Kirby  Vodka, Triple Distilled, Twist of Vanilla
# aisle_id                   83                                        124
# department_id               4                                          5
# prices                   13.2                                        5.3
#
# product_id                                  49685             49686  \
# product_name   En Croute Roast Hazelnut Cranberry  Artisan Baguette
# aisle_id                                       42               112
# department_id                                   1                 3
# prices                                        3.1               7.8
#
# product_id                                          49687  \
# product_name   Smartblend Healthy Metabolism Dry Cat Food
# aisle_id                                               41
# department_id                                           8
# prices                                                4.7
#
# product_id                      49688
# product_name   Fresh Foaming Cleanser
# aisle_id                           73
# department_id                      11
# prices                           13.5
#
# [4 rows x 49693 columns]

# %%
# 13
df_dep_t_new.to_csv(r'/Users/mattrauth/Desktop/Instacart Basket Analysis /Data/Prepared Data/ departments_wrangled.csv')
